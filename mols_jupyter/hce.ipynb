# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
# # HCE Benchmark (Exploit)

# %% [markdown]
# ### Best of Dataset

# %%
smiles = ['[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12',
          'c1ccc(cc1)-c1ccc2c(c1)c1cocc1c1ccccc21', 
          'c1ncc(s1)-c1cnc2c(c1)[se]c1c2oc2ccc3nsnc3c12', 
          '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12']

values = [16.69, 2.968, -10.172, 25.557]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=4,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# ### Random SELFIES
# #### Dipole

# %%
smiles = ['NC(=CC=CC=CO)OF', 
          'S=CC=CC=Cc1ccccc1C=CC=CC=C=Cc1ccccc1', 
          'CC(C=CC=CBr)=CC=CC=CN', 
          'NC=CC=CC=O', 
          'OC=CC=CC=C=PI'
          ]

values = [10.328, 7.458, 7.448, 7.423, 6.548]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# #### Homo-Lumo

# %%
smiles = ['PCl', 'PCl', 'PCl', 'PCl', 'PCl']

values = [4.995510912811, 4.99212901118, 4.991870807158, 4.991419760539, 4.991416247809]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# #### Function

# %%
smiles = ['NC(=CC=CC=CO)OF', 
        'S=CC=CC=Cc1ccccc1C=CC=CC=C=Cc1ccccc1',
         'CC(C=CC=CBr)=CC=CC=CN', 
         'C=CC=CC=C=CC=CC=C=C=NI', 
         'NC=CC=CC=O']

values = [20.503605547038, 16.949922426659, 16.034, 15.9505, 15.914100000000001]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# #### Lumo

# %%
smiles = ['FF', 'FF', 'FF', 'FN=S', 'S=S']

values = [-10.4751, -10.4751, -10.4751, -10.3758, -10.2514]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# ### GB-GA
#
# #### Dipole

# %%
smiles = ['C1=NCC2C3=CCC=C3c3ccsc3C2=N\n',
          'C1=Nc2c([nH]c3c4c(ccc23)=C[SH]=NC=4)C1\n',
          'NC1CC2=C[SiH2]C=C2C2C3OC4C=C[SH]=[Se]C4C3C3CSCC3C12\n',
          'c1cc2[se]c3cc4cc(-c5cc6[nH]c7c(sc8ccc9c[nH]cc9c87)c6c6cscc56)cnc4cc3c2cn1\n',
          'C1=CSC(c2sc(C3=c4cc[nH]c4=C4CNCC4=[SH]3)c3[nH]ccc23)=CO1\n']

values = [15.194, 15.1, 17.031, 15.273, 17.856]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# RDKit ERROR: [02:52:33] SMILES Parse Error: unclosed ring for input: 'C1=NCC2C3=CCC=C3c3ccsc3C2=N
# RDKit ERROR: '
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8ACEB65D0>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles = ['C1=CCC2=NOC3SCCOC3C2=C1\n',
          'C1=C(C2CC3CC4C(CC3C3CCCCC23)c2ccccc2C2COCC24)OCC2NCCCC12\n',
          'C1=CC2=CCCC2=N1\n',
          'C1=CCC2CCC3=NC=CC3C2=C1\n',
          'NSC1=C2Oc3c(c[nH]c3SN)C2CN1\n']

values = [13.02585728763, 5.441462058549, 11.889402720529, 5.244085029962, 10.231499575164]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A98CCE90>

# %% [markdown]
# #### Function

# %%
smiles = ['C1=c2[nH]ccc2=C(Cc2cc3c(ccc4ccccc43)[nH]2)[SH]=[SH]1\n',
          'C1=c2c(-c3ccccc3)cc3c4c[nH]cc4c4c5ccccc5sc4c3c2=C[SiH2]1\n',
          'C1=CC2=C(C3=CC=[SH]C=C3)[SH]=C3C(=C2CS1)CCC1CCCNC31\n',
          'C1=C2CCNCC2=C2SC3=Cc4cnc5c(cnc6ccncc65)c4[SiH2]=C3C12\n']

values = [38.455218234515, 25.253781412671998, 27.36249226463, 26.948228820208]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3F50>

# %% [markdown]
# #### Lumo

# %%
smiles = ['C1=C2C(c3nccc4nsnc34)=COC(c3ccc[nH]3)C2=NC1\n',
          'c1ncnc(-c2ccc(C3=NCSN=N3)c3cscc23)n1\n',
          'c1cc2c(c(-c3cncc4nsnc34)n1)=NNSN=2\n',
          'C1=NC2C[SiH2]=C(c3ccc4nccnc4c3)C2N=C1\n',
          'c1cc2c(s1)=C(c1cncc3nsnc13)[SH]=N[SH]=2\n']

values = [-9.9178, -10.0816, -9.9806, -10.0857, -9.7579]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81B2B50>

# %% [markdown]
# ### VAE SMILES
# #### Dipole

# %%
smiles = ['[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(ccc3c1c1ccncc21)-c1cncc2nsnc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(ccc3c1c1cscc21)-c1cccc2ccccc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1ccccccc1',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(sc3c1c1cscccc21)-c1cccc2cscc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(cnc3c1c1ccncc21)-c1ccc2nnsnc12']

values = [7.3, 3.883, 4.985, 6.71, 8.461]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3290>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles = ['c1ccc(o1)-c1ccc(cc1)-c1cccc2ccccc21',
             'c1ccc(cc1)-c1Cc2c(C1)c1ccccc1c1ccccc21',
             'c1ccc(cc1)-c1ccc2c(c1)c1ccccc1c1ccccc21',
             'c1ccc(cc1)-c1Cc2c(C1)c1ccccc1c1ccccc21',
             'c1ccc(cc1)-c1ccc2c(c1)c1ccccc1c1ccccc21']

values = [2.818039636903,
             2.994150598987,
             3.122880833085,
             3.003759987648,
             3.117462424471]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D8F10>

# %% [markdown]
# #### Function

# %% [markdown]
# #### Lumo

# %%
smiles = ['c1ccc(s1)-c1cnc2c(c1)nc1cccccsccCCCCCccc21',
         'c1ccc(s1)-c1ccc(cn1)-c1Cc(cc1)-c1ccc2cccc12',
         'c1ccc(s1)-c1cnc2c(c1)oc1c2c2cnncccc3nsnc3c12',
         'c1ccc(s1)-c1ccc2c(c1)nc1c2cnc2ccccc3cccc3c12',
         'c1ccc(s1)-c1cnc2c(c1)[se]c1c2c2ccccccccccccc12']

values = [-8.6987, -8.5737, -8.983, -9.228, -8.9166]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D8550>

# %% [markdown]
# ### VAE SELFIES
# #### Dipole

# %%
smiles = ['[SiH2]1C=CC5=C1C=4C2=CSC=C2C=3C=C([Se]C=3C=4C6=NSC=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C([Se]C=3C=4C6=CSC=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C([Se]C=3C=4C6=CSC=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=CC5=C1C=4C2=CSC=C2C=3C=C([Se]C=3C=4C6=CSC=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=C5C=C1C4=C2C=CC=C2C=3C=C([Se]C=3C4C6=CSC=C56)C=NC7=CN=NN=N7']

values = [22.11, 23.718, 23.955, 21.868, 19.131]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D33D0>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles = ['C1C=C3C=C1CC2=C[NH]C=C2CC=C(OC#CC=CCC=C3C4)CC=CC5=COC=C45',
         'C1C=C3C=C1CC2=C[NH]C=C2CC=C(OC#CC=CCC=C3C4)CC=CC5=COC=C45',
         'C1C=C3C=C1CC2=C[NH]C=C2CC=C(OC#CC=CCC=C3C4)CC=CC5=COC=C45',
         'C1C=C3C=C1CC2=C[NH]C=C2CC=C(OC#CC=CCC=C3C4)CC=CC5=COC=C45',
         'C1C=C3C=C1CC2=C[NH]C=C2CC=C(OC#CC=CCC=C3C4)CC=CC5=COC=C45']

values = [3.282472643546,
         3.282472643546,
         3.282472643546,
         3.282472643546,
         3.282472643546]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D8050>

# %% [markdown]
# #### Function

# %%
smiles = ['[SiH2]1C=CC5=C1C=4C2=CSC=C2C=3C=C([Se]C=3C=4C6=NSN=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C([Se]C=3C=4C6=CSC=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=CC5=C1C=4C2=CSC=C2C=3C=C(SC=3C=4C6=NSC=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C([Se]C=3C=4C6=CSC=C56)C=7SC=C8CC[Se]C=78',
         '[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C([Se]C=3C=4C6=NSC=C56)C=7SC=C8CC[Se]C=78']

values = [29.782798093460997,
         32.763253100258,
         30.45063107021,
         32.994020161373,
         33.066532540040996]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D82D0>

# %% [markdown]
# #### Lumo

# %%
smiles = ['[SiH2]1C=CC5=C1C=4C2=CSN=C2C=3C=C([Se]C=3C=4C6=CSN=C56)CSC=C8N=C7SN78',
         '[SiH2]1C=CC5=C1C=4C2=CSN=C2C=3C=C([Se]C=3C=4C6=CSN=C56)CSC=C8N=C7SN78',
         '[SiH2]1C=CC5=C1C=4C2=CSN=C2C=3C=C([Se]C=3C=4C6=CSN=C56)CSC=C8N=C7SN78',
         '[SiH2]1C=CC5=C1C=4C2=CSN=C2C=3C=C([Se]C=3C=4C6=CSN=C56)CSC=C8N=C7SN78',
         '[SiH2]1C=CC5=C1C=4C2=CSN=C2C=3C=C([Se]C=3C=4C6=CSN=C56)CSC=C8N=C7SN78']

values = [-9.8636, -9.8636, -9.8636, -9.8636, -9.8636]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7810>

# %% [markdown]
# # HCE Benchmark (Explore)
# ### GB-GA
#
# #### Dipole

# %%
smiles = ['C=C(C=CC=CC=CNC)OC1=CC=C(C=CC=CC=C=S)C1I\n',
          'Clc1c(C=CC=CI)cccc1C=CC=CC=CI\n',
          'OCC=CC=C1C=C(Br)C(OI)=CC1\n',
          'N=CC=CC=CC1=CC(S)=CC1\n',
          'ClC1CC=C(c2ccccc2-c2ccccc2I)C(I)=C1I\n']

values = [15.058, 16.736, 18.416, 24.652, 15.127]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7290>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles = ['c1ccc(Cc2ccccc2-c2ccccc2-c2ccccc2-c2ccccc2-c2ccccc2)cc1\n',
         '[H]C1COCOC1OCON\n',
         'FC=COc1ccccc1I\n',
         'Fc1ccccc1Cc1ccccc1OCCc1ccccc1CCc1ccccc1\n',
         'CC(N)=Cc1ccccc1C\n']

values = [17.372426579273,17.372525832553,17.372477772102,17.3724330884,17.372358933046]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7ED0>

# %% [markdown]
# #### Function

# %%
smiles = ['C=CC=CC=C=CC=CC=CC1=C(C=CC=S)CC=C1\n',
         'O=C=C=CC=CC=CC=CC=CC=CC=CC=CC=CC=C=C=O\n',
         'BrSC=CC=C=CP=C=CI\n',
         'CC(C=CC=CSF)=CC=CC1=C(OF)C=CC1N=C=CC=CC=CP=N\n',
         'S=C=C=C=CC1=C(C=C=PI)C=CC1\n']

values = [26.248999248282004, 26.741462429212998, 25.561913136745, 32.226542490986006, 30.613003977549]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7890>

# %% [markdown]
# #### Lumo

# %%
smiles = ['ON(F)C=POC=CON(F)F\n',
         'FC=CCC1=C(N(F)S)CC(N(I)c2ccccc2C=CC=C=CC=CC=C=S)=C1\n',
         'O=CC=CC=C=C=CC=CC(F)=CC=C(F)C=CC=C=C=CC=CC=O\n',
         'C#CC=CC=CSCCCC=CC=CC=CC=C=CCC=CC=CCBr\n',
         'C=CC=CC=C(C=CC=C=NC=C=S)P=S\n']

values = [12.0513, 12.0513, 12.0513, 12.0513, 12.0513]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81EAA90>

# %% [markdown]
# ### JANUS
#
# #### Dipole

# %%
smiles = ['C=NN=CCC[PH](C)=CC=CC=CC=C=NF',
             'NC=CC=CC=C(Br)OF',
             'CNCNC=CC=CC=C[PH](=CC=CC=C=C=O)OSC',
             'C=CC=CC=C=C[PH]1=CCS2=CC1=CC2=[PH](I)OCl',
             'C[PH](N=C=C=PI)PN']

values = [23.561, 17.753, 20.339, 20.675, 13.554]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D8C50>

# %% [markdown]
# #### Homo-Lumo

# %% [markdown]
# #### Function

# %%
smiles = ['C=CS1=CCCC[SH]=C(P)C=[SH]SC=[PH]=C1C=CC=CC=P',
         'CN=C=CC=NC#CC=CC=CC=C=C=CC=C(OBr)SC=O',
         'CC(ONC=CP=PC=NPNBr)[SH]=N',
         'C=CC(C=CC=CC=C(C=C=O)N=O)=CN1C=C1',
         'C=CCC(C=CNN)=[PH](C)C=CC=COO[SH]1#[PH]N=NC#P=PN1C=O']

values = [27.983306426636,
             41.957661237825995,
             22.3598,
             30.426462664918,
             31.264073209838003]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81EAD10>

# %% [markdown]
# #### Lumo

# %% [markdown]
# ## GB-GA (Surrogate)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['C1=C(c2ncncn2)C=C(c2cc3c(s2)=C(Cc2ncncn2)NCN=3)C1\n',
                 'C1=NCC(c2ncncn2)=C1c1ccc(C2=c3cc[nH]c3=CC=[SH]2)c2cocc12\n',
                 'c1ccc2c(c1)c1c[nH]cc1c1cc3cc(-c4ncncn4)ccc3cc21\n',
                 'c1ncnc(-c2cc3c4nsnc4c4c(ncc5ccc6c[nH]cc6c54)c3c3nsnc23)n1\n',
                 'C1=Cc2c(-c3cc4c(c5c3=C[SiH2]C=5)=C(c3c[nH]s3)CN=4)sc(-c3cccc4c[nH]cc34)c2C1\n']

values = [2.605, 10.062, 5.349, 7.766, 5.479]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3810>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles =  ['C1=COC(C2=Cc3ccccc3C2)O1\n',
           'C1=Cc2cc3c(cc2CC1)-c1[se]ccc1C1=[Se]C=[SH]CC13\n',
           'c1ccc(-c2ccccn2)cc1\n',
           'C1=[Se]C(c2cc3cc4c(cc3[nH]2)CN=[SiH2]4)=CC1\n',
           'C1=CNC2[SiH2]C=C(c3cc4ccccc4c4c3=[SH]SC=4)C2=C1\n']
                                    

values = [3.130577868908, 1.52336102006, 2.83270082355, 0.029407896567, 0.343307497506]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB9285DBB50>

# %% [markdown]
# #### Function

# %%
smiles =  ['C1=c2[se]ccc2=C(c2nccc3nsnc23)[SH]=[SH]1\n',
           'C1=CC2CN=[SH]C(c3sc(-c4scc5[nH]ccc45)c4c3[Se]=NS4)=C2[SiH2]1\n',
           'C1=CSc2c(C3=CN=[SH]C=C3)sc(-c3cnc4c(cnc5c4[nH]c4ccoc45)c3)c2O1\n',
           'c1cc(-c2ncncn2)c2c[nH]cc2c1\n',
           'c1cc2cc3c4c[nH]cc4c4cc(-c5scc6c5CNC6)c5nsnc5c4c3cc2o1\n']


values = [12.134408501273999, 16.607059520065, 12.2619, 13.307300000000001, 14.0265]


mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A9D12950>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['C1=NC=c2cc(-c3cnc(Cc4scc5nccnc45)c4nsnc34)c3cccnc3c2=[SH]1\n',
           'C1=N[SH]=C(C2C(c3cncc4nsnc34)=C(c3ccco3)c3nsnc32)c2nsnc21\n',
           'C1=[SH]C(c2cncs2)C(c2sc(-c3cncc4nsnc34)c3ccoc23)=C1\n',
           'C1=NSN=C(c2ncc(-c3cccc4cocc34)c3nsnc23)N1\n',
           'Clc1ncnc(C2=[SH]C=C3CC=CC32)n1\n']

values = [-8.7778, -8.7543, -8.2271, -8.9464, -7.5567]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D38D0>

# %% [markdown]
# ## JANUS (SURROGATE)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['C#Cc1cc(-c2scc3[nH]ccc23)sc1C(c1c(-c2ncncn2)ncc2c[nH]cc12)C1(C)CN=CC1=CCCC=C',
         'CC12CC(c3scc4[nH]ccc34)=C(CC=CCC=C1C=C=Cc1cccc3c1pc(-c1ncncn1)c1c[nH]cc13)CS2',
         'C=C1[SiH2]C=C(c2scc3[nH]ccc23)P1#CC=C1Cc2cc3c(cc2N1)cc(-c1ncncn1)c1c[nH]cc13',
         'CCCC=C=c1cc2oc1=C1CC=CC(=C(c3scc4[nH]ccc34)C2)c2c[nH]cc2CC=C=C(c2ncncn2)C=[SH]C1',
         'FCC=c1cc[nH]c1=C[SiH2]C=CC1C=c2c(ccnc3cc(-c4ncncn4)c4c[nH]cc4c3cc3cocc23)=N1']

values = [7.058, 6.774, 7.283, 10.832, 3.202]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8ACEB5CD0>

# %% [markdown]
# #### Function

# %%
smiles =  ['C=C=CC(C=C=C(C)Cc1c[nH]cc1C1=C2PC[Se]C2=C(c2ncncn2)CC1CS)c1scc2[nH]ccc12',
             'C=NC=S1C=CC=Nc2cncnc2-c2c[nH]cc2CC(N[SiH2]C=CNC23CC#CN2C=CC=CS3)[SH]=CC1',
             'SN=C1C(=NCNC=CCNS)C2=CCC#CCC=Cc3c[nH]cc3CC=CSCC=CN=C2c2c1cc(-c1cncs1)c1nsnc21',
             'C=C1S#CC=C(c2scc3[nH]ccc23)CCC(=CCN=C2[Se]CSC2=CCc2ncncn2)[SH]1CC=CC=c1cc2oc1=CC2',
             'C#CNNNC1CN=Cc2sc(-c3scc4[nH]ccc34)c3c(c[nH]c23)CC=[SH]C=CN=CC=NC1c1cncc2nsnc12']

values =  [17.9882, 16.584276449716, 18.616122144959, 12.2107, 11.865021548805]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D8D50>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles =  ['C=C1C=CS(CCC2=NC(=C)C(CC)=C=C3CCCNC34C=CC4CC2)=CC1',
         'C=CC=C=c1sccc1=CC1Cc2c3cc4c(c2=C2Oc5ccc(nc5C2(C)C1)N4)=CC=CC=CC1=CNCN13',
         'CCCC=C=CC=CC=CC=C=C1C2(C)CC3=CC12C(C)=C(NC#CN)C=NSON=CC3',
         'CCc1c(N=CCC=C=CCCC=c2ccsc2=CC2C#CCC=CCCCCC=CC=PSCNC=C2)csc1C',
         'C#Cc1c[se]c2c1C1=[SH]C3=CC1(C2)N=C=C3']

values =  [0.884023333021, 0.986739516342, 0.045934430188, 1.319041589497, 1.530632176977]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A98C4C50>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['CCC=CC=CSCNC1=C2CC(=CC3=C(c4ncc(-c5cncc6nsnc56)c5nsnc45)C(=NN)C3)[SH]1C=C2NC',
             'NSCc1ccncc1-c1ncc(C2=NCCC2N=C[SH]=NCC=CC=CCCNSNC=CCC=[SH]=NCc2ncncn2)c2nsnc12',
             'CCC=C1C=C1CCNCC=CC=Cc1cc(N)cc2c1CN2CC(CS)c1ncc(-c2cncc3c2=[SH]SN=3)c2nsnc12',
             'C#CSNCCC=CC1=C(C2=CN=C=C2)SC(NCPCN=NC)=C=CN(C=c2cc3[se]c2=CN3c2cncc3nsnc23)C1',
             'C#CSc1cc(-c2ncc(C3=C=NC=C3c3cncc4c3=N[SH](C3=CC=C=C3)N=4)c3nsnc23)sc1-c1cncs1']

values =  [-8.351, -8.2542, -9.0185, -8.9109, -9.2089]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D30D0>

# %% [markdown]
# ## VAE SELFIES (SURROGATE)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['C1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C(SC=3C=4C6=NSC=C56)C=7SC=C8[NH]C=CC=78',
             'C15C=CC=C1C=4C2=C[NH]C=C2C=3C=C(OC=3C=4C=NCN=C5C)C6N=CC7=NC=NC=C67',
             '[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C3=CC(=CN=C3C=4C6=NSC=C56)CSC7=CC=NC=N7',
             'C15C=CC=C1C=4C2=C[NH]C=C2C=3C=C(OC=3C=4C=NCN=C5C)C6N=CC7=NC=NC=C67',
             'C1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C(SC=3C=4C=NCN=C5C)C6C=CC7=NC=NC=C67']

values =  [2.69, 5.161, 4.966, 5.109, 9.44]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A8393910>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles =   ['C12C=CC=C1C=CN=CN=C=CN=C(NC(=CN=CP3C)C23C)C4=CS=C=C5CSC=C45',
             '[SiH2]124C=CC=C1C=NC=CC3C25N=NC=CCNC3C=CPC=C4C5C6NC6',
             '[SiH2]125C=CC=C1C=CC=CC=C2C=3C=C(NC=3CC4C6=N4)C5N=NC6',
             'C13C=CC=C1C=CC=NC=C(C=NCCC2=CC=CC=CC=CC2)C=C3',
             'C1C=C5C4=C1CS2CC=CC2CC=CC=CSC=CC=C(NC=3)C=3C4C6=CC=CC=C56']

values =  [1.076566755945, 2.722383786657, 0.201296199199, 1.323152889483, 1.449022053821]


mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D31D0>

# %% [markdown]
# #### Function

# %%
smiles =  ['[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C(SC=3C=4C6=NSC=C56)CSC7=CC=NC=N7',
             '[SiH2]1C=C4C=C1CC2=C[NH]C=C2C=3C=C(NC=3CC=NSC=C4CSC5=CC=NC=N5)',
             'C1C=CC=C1CC2=C[NH]C=C2CC=C([SiH2]C#CNC3=CSN=C3CSC=CC=C4SN4)',
             'C1C=CC=C1CC2=C[NH]C=C2C3C4=C3C=CC4CC=CC=CC=CC(=C)C5=CC=NC=N5',
             '[SiH2]1C=CC5=C1C=4C2=C[NH]C=C2C=3C=C(SC=3C=4C6=NSN=C56)C=7SC=CN=CSN=7']

values =  [14.5968, 10.7827, 10.5782, 11.319099999999999, 15.503499999999999]


mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7250>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['[SiH2]13C=CC=C1C2=NC=CC=C=CN=C(S#CC2C=NSC=C3C4=CN=CC5=NSN=C45)',
         '[SiH2]C=C3C(=C=C1SN=CC1NCCN=CCN2N=C2(C3))C4=CN=CC5=NSN=C45',
         'C15C=CC=C1CSCCS=2C=4C=CC=3COCC=CC=2C=3C=4C=CC5C=CCNON',
         'C1C=C5C=C1C=4C2=CSN=C2C=3C=C([SiH2]C=3C=4C6=NSN=C56)C7=CN=CC8=NSN=C78',
         '[SiH2]14C=C3C2=C1C=NCNC(C)=C(NC5C23ON=C45)C6=CN=CC7=NSN=C67']

values =  [-8.7745, -7.9671, -6.6667, -8.5286, -8.3462]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3950>

# %% [markdown]
# ## VAE SMILES (SURROGATE)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(csc3c1c1csccc21)-c1cncc2cscc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(ccc3c1c1ccccc21)-c1cncc2cscc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(csc3c1c1csccc21)-c1cncc2cscc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(csc3c1c1csncc21)-c1cncc2nsnc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12']

values =  [5.308, 4.817, 5.320, 6.821, 5.132]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83932D0>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles =  ['[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(cnc3c1c1ccccc21)-c1scc2ccsc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(ccc3c1c1ccccc21)-c1scc2ncsc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2ccsc12',
         '[nH]1cccc1C1=Cc2c([SiH2]1)c1cccscccccccccccccccccccccccccc21',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(cnc3c1c1ccccc21)-c1scc2ccsc12']

values =  [1.778137498734, 1.762893545976, 1.416572344007, 0.89373658579, 1.77804569107]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A8393E10>

# %% [markdown]
# #### Function

# %%
smiles =  ['[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12',
         '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12']

values =  [14.0535, 14.0525, 14.0508, 14.0534, 14.0516]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83A2350>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12',
                 '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(ccc3c1c1cscc21)-c1cncc2nsnc12',
                 '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(cnc3c1c1ccncc21)-c1cncc2nsnc12',
                 '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc([se]c3c1c1cscc21)-c1scc2sccc12',
                 '[SiH2]1C=Cc2c1c1c3c[nH]cc3c3cc(ccc3c1c1ccccc21)-c1cccc2nsnc12']

values =  [-7.9194, -8.5177, -8.3038, -7.9189, -8.1738]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A839A050>

# %% [markdown]
# ## GB-GA Explore (Surrogate)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['O=C=CC=CC=CPC1=C(PC=CC=C=CF)CC=C(Cl)C1\n',
             'S=NPC=CCOOC=CN=C=CC=CC=C=CC=CPC1=CC=CC1\n',
             'O=C=CC=CC=CC=CC=Cc1ccccc1\n',
             'O=C=CC=CC=CC=C=O\n',
             'FNN=NC=C(C=CCl)C=CC=C=CC=CC=CC=C=S\n']

values =  [2.049, 4.905, 1.018, 0.002, 2.155]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A9D09490>

# %% [markdown]
# #### Function

# %%
smiles =  ['FC1=C(C=CC=CC2=CC=CC2)C=C(C2=CCC(C=CC=C=S)=C2C=S)C1\n',
             'FC=C=CC=CPC=C=CC=CPc1ccccc1\n',
             'O=C=CC=CC1=C(Sc2ccccc2C2=CCc3cc2c[nH]3)CC=C1C=C=O\n',
             'C#CC=CCSc1cccc(C=CC=C=O)c1C=CCC=CS\n',
             'FC=Cc1cccnc1\n']

values =  [16.16462490453, 9.1311, 13.196404057521, 11.9892, 10.6633]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A9A75190>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles =  ['CCSC1=C(CC2=CC=CC2)Cc2c(I)cccc21\n',
             'PN=PC=CC1C=CC=C1C1=CCCC=C1c1ccccc1\n',
             'ClC=CC=C=CC=C1C=CC=CP1\n',
             'ClCCCCCCI\n',
             'FC(=CC=C=C=CC=S)c1ccccc1S\n']

values =  [2.592438558644, 1.855339348288, 1.881355143316, 4.65503137293, 0.414608140591]


mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A98BACD0>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['N=NC=CN=N\n',
         'C=C[SH]=C[SH]=CC=C=S\n',
         'C=CC=C(N)C=CC(=C)C=CC=CN=N\n',
         'FNC=CC=C(I)C=CC=CCl\n',
         'C=CC=COC=CBr\n']

values =  [-8.4875, -8.3418, -8.4066, -8.0505, -7.2242]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8AD409050>

# %% [markdown]
# ## JANUS Explore (Surrogate)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['O=C=NOC=PCC=C=CCC=CC=CPC1=PC(=C=CCC=C=C=NC=C=CC=CC=CCBr)CC=CCCN=C=CC=C=CC=CN1',
         'CCCC=c1cnccc1=CC(C=C=CCC=CNC=C=[SH]CC=CC=C=CCC=C=CC=C=[SH]S)C=CC=C(C)C=C=S',
         'CC1=NNCC(CPCCC=CCC=C=P)C(=CC=CPC2=C([SH]=C=CC=CC=C=S)C=CCC(CC=CC=C=O)=CC#C2)CC=C1',
         'CC(C=C=S)=CC=C=CCCCC=C=CC=C=[SH]CC=CC=[PH]C=CCC(C=CCCl)CSC=C(C)C=CC=CP=CC=CC=C=O',
         'S=C=CC=C(C#CC=CC=CC[SH]=C=CCC(C=CCC#CPCC=CCBr)[SH]=CC=C=[SH]C=CCCl)C=C=S']

values =  [3.571, 2.049, 3.998, 4.85, 1.989]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A822C950>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles =  ['CCC(CO)C1=C=CC(C)=CC1',
             'Brc1ccccc1OCCC=C=CCC=Nc1ccccc1I',
             'CCC1C(CCOc2ccccc2OCCC=C=CCPOCCC2=CCC=CC2I)=CC=CCC1(C)CF',
             'O=[PH]=C=CC=CC=CC=C=CCCC=C=CCOC1C=CN=C=P1',
             'CC[PH](=CSN=CCCC=C=CC=CC=CSC=CC=CC=CC=CC=C=CNSN)C1(C)C=C1']

values =  [1.858640256419, 2.956846155542, 2.714767065867, 1.210256117925, 1.549347979814]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81EAC90>

# %% [markdown]
# #### Function

# %%
smiles =  ['C#CC(C=CC=C=O)C1(CC=CC(CCC)[SH]=CC=CC=CC=CC)CCC#CSC(=C=N)C(=CCC=C=[SH]=C=CC)C1',
 'C=CNC1C(CC)=C(C2C(C=CS3=C=CC=CCSC3)=C=CC=C2PC=CC=CC=C=O)C1C=CC(C)C=CCC=CC',
 'C#CC=CCC1=CCCN=CC(C=CC=C=O)CC1=CC=C(C=C)OCC=CCC(I)COC=NC(CC)CC=CC=CC=O',
 'CC(C=CCC#CC=C[SH]=CCC=C=[SH]=C=CC=CP=CNC=CCCCC=CC=C=S)CS1=CC=CC=C1PC=CC=C=O',
 'C#CC=CC=CC(=CCC1=CCC=CC#CC=NCCC1=C=COCC=CCC=CC=C=O)C(O)=CC=CC(=C=CCS)CCCC=CI']

values =  [13.177, 10.645248023191, 16.3442, 15.698550333052, 12.568899182663]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A8393A50>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['C=C(S)C=CC=CC(C)=CC=CC=[SH]=[SH]#[PH]OCCCl',
         'N[SH]=CC=[SH]S',
         'S=C=C=CC=S',
         'OC=COP=[SH]=[SH]C=C=CP=CC=C=CC=COO',
         'CCC[PH]=C=[SH]C=N']

values =  [-7.4073, -9.0533, -10.0628, -8.0184, -7.6394]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81EA610>

# %% [markdown]
# ## JANUS Biased Actual

# %% [markdown]
# #### Dipole

# %%
smiles =  ['CN=[SH]CN=C1C=C[Se][SH]2(C1)C(CC=NCC=C(N)C(C=NC=NC=NSCCCSN)=CN)C[Se]C[SiH2]2C',
             'CC(=CC=CC1C=C1c1c[se]c(C=C[SiH2])c1)C(=NC=C[Se])NC=C=CCCCC=C=C=CC=COCC#N',
             'SC=CC=CSC=C1c2c[nH]c3c2=C[SH]1C=3c1cc2c3nsnc3c3c([se]c4ccc5c(c43)=C[SiH2]C=5)c2s1',
             'CC1=C[SH]2(=CCC=CC#N)[SiH2]C1=C2C(C)=CNC=CC=CC=CNc1ccncc1C[Se]',
             'C=C=Cc1ccsc1C1SC2=CN=CCC3=CC4=N[SH]1C41CC4=C[SiH2]C=C4C=CC([Se]C2)C1=C3']
values =  [22.113, 23.4, 17.849, 29.432, 16.627]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A839AAD0>

# %% [markdown]
# #### Homo Lumo

# %%
smiles =  ['C=C(S)C=CC=CC(C)=CC=CC=[SH]=[SH]#[PH]OCCCl',
         'N[SH]=CC=[SH]S',
         'S=C=C=CC=S',
         'OC=COP=[SH]=[SH]C=C=CP=CC=C=CC=COO',
         'CCC[PH]=C=[SH]C=N']

values =  [-7.4073, -9.0533, -10.0628, -8.0184, -7.6394]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D8FD0>

# %% [markdown]
# #### Function

# %%
smiles =  ['C',
         'C',
         'C',
         'C',
         'C']

values =  [17.372458775728, 17.373664640964, 17.373664640964, 17.372458775728, 17.373664640964]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3E10>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['CC1C2=c3c#c[se]c3=CCSC1(I)C2Br',
         'c1cc(C2=C3[Se]C4=C3C(C=NCc3nsnc34)S2)sc#1',
         'C1=NSCC2=C3N=C4C5=NSN(C6C7=CSC6=C(CON=C73)SS36C=N[SH]3N16)C542',
         'C1=CC2C=C3SCC4CC3=NN=CP=[SH]C3=NSSN3C(=CC4S1)SC2',
         'S=C1N=NN=C1Br']

values =  [-10.7828, -10.2272, -10.2257, -10.0332, -11.3494]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3A50>

# %% [markdown]
# ## Hill Climbing SMILES (Biased)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['C1=c2c(-c3scc4cc[nH]c34)cc3cc4[se]c5ccc6cscc6c5c4cc3c2=C[SiH2]1', 'c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1', 'c1cc(-c2cc3cnc4c5sccc5c5c[nH]cc5c4c3[nH]2)c2c[nH]cc2c1', 'c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1', 'C1=c2c(-c3scc4cc[nH]c34)cc3cc4[se]c5ccc6cscc6c5c4cc3c2=C[SiH2]1']
values =  [12.651, 12.314, 9.464, 12.195, 16.22]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7B90>

# %% [markdown]
# #### Function

# %%
smiles =  ['c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1', 'c1cc(-c2cc3cnc4c5sccc5c5c[nH]cc5c4c3[nH]2)c2c[nH]cc2c1', 'c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1', 'c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1', 'c1cc(-c2cc3cnc4c5sccc5c5c[nH]cc5c4c3[nH]2)c2c[nH]cc2c1']
values =  [20.929470249551002, 17.5612, 21.039044729617, 20.956925632365, 17.5584]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81EAD50>

# %% [markdown]
# #### Homo Lumo

# %%
smiles =  ['c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1',
         'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1',
         'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1',
         'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1',
         'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1']

values =  [2.73024013, 2.73049165, 2.73048162, 2.73022839, 2.73022578]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7910>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['C1=Cc2c(csc2C2=Cc3c(c4sc5ccc6cocc6c5c4c4cocc34)C2)[SiH2]1', 'C1=Cc2c(csc2-c2cc3ncc4c(ncc5ccc6nsnc6c54)c3c3ccccc23)[SiH2]1', 'C1=Cc2c(csc2-c2ccc3c(ccc4c5ccccc5[se]c34)c2)C1', 'c1cc2c(-c3cc4ccc5c(ccc6ccc7c[nH]cc7c65)c4[nH]3)scc2[se]1', 'C1=c2ccc3cc4c(cc3c2=CC1)c1oc(-c2cccs2)cc1c1nsnc41']

values =  [-9.6243, -9.2446, -9.2949, -9.2937, -9.4032]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3510>

# %% [markdown]
# ## Hill Climbing SELFIES (Biased)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1',
             'c1cc(-c2cc3cnc4c5sccc5c5c[nH]cc5c4c3[nH]2)c2c[nH]cc2c1',
             'c1cc(-c2cc3cnc4c5sccc5c5c[nH]cc5c4c3[nH]2)c2c[nH]cc2c1',
             'C1=Cc2c(c3c(c4c[nH]cc24)-c2[nH]c(-c4nccc5nsnc45)cc2C3)[SiH2]1',
             'c1cc(-c2cc3cnc4c5sccc5c5c[nH]cc5c4c3[nH]2)c2c[nH]cc2c1']

values =  [12.284, 9.472, 9.469, 12.051, 9.471]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81EA490>

# %% [markdown]
# #### Function

# %%
smiles =  ['c1cc(-c2cc3cnc4c5sccc5c5c[nH]cc5c4c3[nH]2)c2c[nH]cc2c1', 'c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1', 'c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1', 'C1=c2c(-c3scc4cc[nH]c34)cc3cc4[se]c5ccc6cscc6c5c4cc3c2=C[SiH2]1', 'c1cc2c(-c3ccc(-c4ncc(-c5scc6cc[se]c56)c5nsnc45)[nH]3)scc2[nH]1']
values =  [17.566     , 20.92097468, 21.04346397, 24.57805633, 22.70118382]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83A2A50>

# %% [markdown]
# #### Homo Lumo

# %%
smiles =   ['c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1', 'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1', 'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1', 'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1', 'c1c[nH]c(-c2cc3[nH]c4c(ccc5cc[nH]c54)c3o2)c1']

values =  [2.730186405779,
             2.730494445517,
             2.729940612558,
             2.730492991994,
             2.730196575098]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83A2E10>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['C1=Cc2c(csc2-c2cc3ncc4c(ncc5ccc6nsnc6c54)c3c3ccccc23)[SiH2]1', 'C1=Cc2c(csc2-c2ccc3c(ccc4c5ccccc5[se]c34)c2)C1', 'C1=Cc2c(csc2C2=Cc3c(c4sc5ccc6cocc6c5c4c4cocc34)C2)[SiH2]1', 'C1=Cc2c(csc2-c2cc3ncc4c(ncc5ccc6nsnc6c54)c3c3ccccc23)[SiH2]1', 'C1=Cc2c(csc2-c2ccc3c(ccc4c5ccccc5[se]c34)c2)C1']

values =  [-9.2703, -9.3054, -9.6235, -9.2694, -9.3043]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83BD490>

# %% [markdown]
# ## REINVENT Biased

# %% [markdown]
# #### Dipole

# %%
smiles =  ['C1=c2c(c3c4cnccc4ncc3c3c2cc(-c2ncncn2)c2c[nH]cc23)=C[SiH2]1',
         'C1=C(c2ncncn2)[SiH2]c2c1c1c(c3c4ncccc4c4c[nH]cc4c23)=CCC=1',
         'C1=C(c2ncncn2)Cc2c1cnc1c3cnccc3c3c[nH]cc3c21',
         'c1ncnc(-c2cc3sc4c5cnccc5c5c[nH]cc5c4c3c3cocc23)n1',
         'C1=C(c2cccc3c[nH]cc23)[SiH2]C(c2ncc(-c3ncncn3)c3nsnc23)=C1']

values =  [3.216, 5.337, 6.369, 7.207, 7.525]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83A2F90>

# %% [markdown]
# #### Function

# %%
smiles =  ['C1=C(c2ncncn2)[SiH2]C(c2sc(-c3scc4[nH]ccc34)c3cc[se]c23)=C1',
             'C1=C(c2scc3[nH]ccc23)CC(c2cnc(-c3ncncn3)c3nsnc23)=C1',
             'c1cc(-c2ccc(-c3cnc(-c4ncncn4)c4nsnc34)c3c2=C[SiH2]C=3)c2c[nH]cc2c1',
             'C1=Cc2c(-c3scc4[nH]ccc34)sc(-c3cnc(-c4ncncn4)c4nsnc34)c2[SiH2]1',
             'c1cnc2c(-c3sc(-c4ncncn4)c4cc[nH]c34)sc(-c3scc4[nH]ccc34)c2n1']

values =  [18.2332, 15.0047, 16.123894953742, 13.013200000000001, 19.943735209137]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83A2110>

# %% [markdown]
# #### Homo-Lumo

# %%
smiles =  ['c1ccc(-c2cc3cnc4c5occc5oc4c3o2)cc1',
             'c1coc(-c2cc3ncc4c5occc5[nH]c4c3o2)c1',
             'c1ccc2c(-c3ccc4c(ccc5c4oc4ccsc45)c3)cccc2c1',
             'c1ccc(-c2cc3ncc4ccoc4c3c3ccccc23)cc1',
             'c1cncc(-c2ccc3c(ccc4c3[nH]c3ccoc34)c2)c1']

values =  [2.794753936525, 2.700321786911, 2.765439375204, 2.676791470448, 2.731034366875]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83AEA50>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['c1csc(-c2sc(-c3cnc(-c4cncs4)c4nsnc34)c3nccnc23)c1',
             'c1ncnc(-c2sc(-c3ncc(-c4cncc5nsnc45)c4nsnc34)c3sccc23)n1',
             'c1ncnc(-c2cnc(-c3nccc4nsnc34)s2)n1',
             'c1c[se]c(-c2sc(-c3ccc(-c4cncc5nsnc45)[se]3)c3nccnc23)c1',
             'c1cc(-c2cnc(-c3ncc(-c4cncc5nsnc45)s3)c3nsnc23)c2nsnc2c1']

values =  [-8.9802, -9.1515, -9.1878, -8.9617, -9.0674]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D3650>

# %% [markdown]
# ## Hill Climbing (Explore) SELFIES

# %% [markdown]
# #### Dipole

# %%
smiles =  ['NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF']

values =  [10.346, 10.357, 10.349, 10.335, 10.322]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A839AD90>

# %% [markdown]
# #### Func

# %%
smiles =  ['NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF']

values =  [20.531326117056, 20.552887431328998, 20.528472416641, 20.522073433674, 20.522197043005]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83BD890>

# %% [markdown]
# #### Homo Lumo

# %%
smiles =  ['PCl', 'PCl', 'PCl', 'PCl', 'PCl']

values =  [4.996126949681, 4.995941413707, 4.996853507103, 5.003463473433, 5.002984345497]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A8393990>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['FF', 'FF', 'FF', 'FF', 'FF']

values =  [-10.4751, -10.4751, -10.4751, -10.4751, -10.4751]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83BDD90>

# %% [markdown]
# ## Hill Climbing (Explore) SMILES

# %% [markdown]
# #### Dipole

# %%
smiles =  ['NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF']

values =  [10.332, 10.367, 10.354, 10.354, 10.358]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81E7E50>

# %% [markdown]
# #### Func

# %%
smiles =  ['NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF', 'NC(=CC=CC=CO)OF']

values =  [20.514323103077, 20.505916745653, 20.528392533069002, 20.518170201469, 20.539300261271002]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A98C9C50>

# %% [markdown]
# #### Homo Lumo

# %%
smiles =  ['PCl', 'PCl', 'PCl', 'PCl', 'PCl']

values =  [4.996854465691, 4.995457937122, 4.993043080919, 4.995723121109, 5.003694643195]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83BF510>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['FF', 'FF', 'FF', 'FF', 'FF']

values =  [-8.9802, -9.1515, -9.1878, -8.9617, -9.0674]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A8393290>

# %% [markdown]
# ## REINVENT (Explot)

# %% [markdown]
# #### Dipole

# %%
smiles =  ['C1=c2c(-c3ccc[nH]3)cc3c4cscc4c4c5cnccc5ncc4c3c2=C[SiH2]1', 'C1=c2ccc3cc4[se]c5cc(-c6nccs6)[nH]c5c4cc3c2=C[SiH2]1', 'C1=Cc2[se]c3c(cnc4cc(-c5scc6cc[nH]c56)c5cscc5c43)c2[SiH2]1', 'C1=Cc2csc(-c3cc4ncc5c6cnccc6c6c[nH]cc6c5c4[nH]3)c2[SiH2]1', 'C1=C[SiH2]C(c2ccc(C3=CC=C(c4scc5[se]ccc45)C3)c3cscc23)=C1']

values =   [9.756, 8.981, 10.114, 9.673, 13.424]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A83BDA50>

# %% [markdown]
# #### Func

# %%
smiles =  ['c1csc(-c2cc3[se]c4c5c6cocc6ccc5c5ccccc5c4c3[se]2)c1', 'c1cc2c(-c3cc4c5c[nH]cc5c5c(oc6ccc7c[nH]cc7c65)c4c4nsnc34)scc2o1', 'C1=Cc2c(csc2-c2cc3cnc4c5c(c6cscc6c4c3[se]2)C=CC5)C1', 'c1cc2c(-c3sc(-c4cnc(-c5scc6[se]ccc56)c5nsnc45)c4[nH]ccc34)scc2[nH]1', 'C1=Cc2c(csc2-c2cc3cnc4c5c(c6cocc6c4c3[se]2)C=CC5)C1']
values =  [19.176898946274, 17.7756, 19.738877385796, 22.718044343899003, 19.880935823861]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB92856ECD0>

# %% [markdown]
# #### Homo Lumo

# %%
smiles =  ['C1=Cc2oc3c(ccc4cc(-c5ccccc5)c5ccccc5c43)c2C1', 'c1ccc2c(-c3cc4[nH]c5c6ccccc6ccc5c4c4ccccc34)cccc2c1', 'C1=Cc2csc(-c3cc4ccc5cc[nH]c5c4cn3)c2C1', 'c1ccc(-c2cnc3c(c2)[se]c2c3ccc3ccoc32)cc1', 'c1ccc2c(c1)c(-c1ccc3ccoc3c1)cc1c2ccc2cc[nH]c12']

values =  [2.55404475662, 2.624584680681, 2.587039841132, 2.661288749985, 2.719881852425]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A81D8B90>

# %% [markdown]
# #### Lumo

# %%
smiles =  ['c1cc2c(-c3cnc4c(c3)[se]c3c4[se]c4ccc5cocc5c43)scc2[nH]1', 'c1cc2c(-c3cc4c5nsnc5c5cc6ccc7cscc7c6c5cc4[se]3)scc2[se]1', 'C1=c2cccc(-c3ccc4c(ccc5c4oc4cc[se]c45)c3)c2=CC1', 'C1=Cc2c(-c3scc4[nH]ccc34)sc(-c3ccc(-c4scc5nccnc45)[se]3)c2C1', 'c1ncnc(-c2sc(-c3ncc(-c4scc5nccnc45)c4nsnc34)c3ccoc23)n1']

values =  [-9.5857, -9.6524, -9.5414, -9.3456, -9.129]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FB8A839A290>
