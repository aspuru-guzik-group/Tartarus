# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
# ### Best of Dataset

# %%
smiles = ['c1cnc(-c2ccc(cn2)-c2ccc(cc2)-c2ncncn2)c2nsnc12',
          'c1c-c2cc3cnc4ccc5ccccc5c4c3cc2-nc1']

values = [7.574779560045929, 31.7087755265395]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=4,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# ### GB-GA

# %% [markdown]
# #### Function 1

# %%
smiles = ['c1ccc2c(-c3cncc4nsnc34)ccnc2c1', 'c1cncc(-c2cncc3nsnc23)c1', 'c1ccc2c(c1)ncc1c3ncc(-c4cncc5nsnc45)cc3c3ccccc3c21', 'c1cncc(-c2cncc3nsnc23)c1', 'c1cncc(-c2cncc3nsnc23)c1']
values = [8.055828973351076, 7.7632192791591805, 7.81210529282769, 7.7632192791591805, 7.7632192791591805]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function 2

# %%
smiles = ['c1cnc2cc3c(cnc4ccc5ccccc5c43)cc2c1', 'c1ncc(-c2cc3c4cscc4c4c(ncc5ccc6c[nH]cc6c54)c3c3cocc23)s1', 'c1cc2csc(-c3ccc4c(c3)c3cscc3c3c5c6c[nH]cc6ccc5c5nsnc5c43)c2[se]1', 'c1coc(-c2cc3cc4cnc5ccc6ccccc6c5c4cc3cn2)c1', 'C1=c2ccc3ncc4cc5cc(-c6scc7cc[se]c67)ccc5cc4c3c2=CC1']
values = [31.711544415807257, 29.653034876785128, 30.24759748642997, 30.455735788781713, 30.19380798665803]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### HCE-SELFIES

# %% [markdown]
# #### Function 1

# %%
smiles = ['C1=CC(c2ccc(-c3ccc(-c4cncc5nsnc45)cc3)o2)=N1', 'c1cncc(-c2cnc(-c3ccc(-c4nccc5nsnc45)nc3)cn2)c1', 'C=Cc1cc2ccncc2c2sc(-c3cncc4nsnc34)cc12', 'N=CCCC(=CCc1cncc2nsnc12)c1ccc(-c2cccnc2)cc1', 'C1=CC(C=Cc2cc3cnc(-c4cncs4)cc3c3cscc23)=N1']
values = [7.7668046297844056, 7.918884505636344, 7.2199415738216555, 7.058260322941427, 7.033245549746491]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function 2

# %%
smiles = ['C#Cc1ccncccc2ccccc2c1', 'C=Cc1c(C=Cc2ccc3c(ccc4ccccc43)c2)ncc2cc[se]c12', 'Cc1c2ccc(cc3ccc-3c3ccccc3c3ccccc13)c([Se])c2', 'C1=Cc2cnc3ccc4ccccc4c3c2Cc2cnccc21', 'c1cnc2cc3c(cnc4ccc5ccccc5c43)cc2c1']
values = [32.022432998373795, 30.805738264466875, 29.828248798485312, 29.195092599679594, 31.710790651813593]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### HCE-SMILES

# %% [markdown]
# #### Function 1

# %%
smiles = ['c1ccc(cn1)-c1sc(-c2cncc3nsnc23)c2sccc1-2', 'c1ccc(cn1)-c1sc(-c2cnc(-c3cccc4nsnc34)s2)nc1', 'c1cnc(-c2ccc(cn2)-c2ccc(-c4cncc5nsnc45)cc2)1', 'c1cnc(-c2ccc(-c3sc(-c4ncncn4)c4[nH]ccc34)nc2)-1', 'c1cnc(-c2ccc(cn2)-c2ccc(cc2)-c2[nH]c3nccnc3c2)1']
values = [6.784651223204054, 5.980152054849558, 7.027234377534031, 6.83223537864604, 6.770682456618891]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function 2

# %%
smiles = ['c1c-c2cc3cnc4ccc5ccccc5c4c3cc2cc1-c1cnccn1', 'c1c-c2cc3cnc4ccc5ccccc5c4c3cc2nc1', 'c1c-c2cc3cnc4ccc5ccccc5c4c3cc2nc1', 'c1c-c2cc3cnc4ccc5ccccc5c4c3cc2nc1', 'c1c-c2cc3cnc4ccc5ccccc5c4c3cc2nc1']
values = [32.05729418308321, 31.718022345269954, 31.718839299785035, 31.719592910313263, 31.7173923746027]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### JANUS

# %% [markdown]
# #### Function 1

# %%
smiles = ['c1cncc(-c2sc(-c3cnc(-c4cccc5nsnc45)s3)c3nccnc23)c1', 'c1cncc(-c2sc(-c3cnc(-c4cccc5nsnc45)s3)c3nccnc23)c1', 'c1ncnc(-c2ccc(-c3ccc(-c4scc5nccnc45)cn3)cn2)n1', 'c1cc2nsnc2c(-c2ccc(-c3ccc4cncnc4c3)cn2)n1', 'c1ncnc(-c2ccc(-c3ccc(-c4nccc5nsnc45)nc3)cc2)n1']
values = [7.516721499438747, 7.516049854116858, 7.470407940935884, 7.859405848140073, 7.57604386926214]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function 2

# %%
smiles = ['C1=Cc2c(c3ncc4ccc5nsnc5c4c3c3cscc23)[SiH2]1', 'c1c-c2cc3cnc4ccc5ccccc5c4c3cc2-nc1', 'c1cnc2cc3c(cnc4ccc5ccccc5c43)cc2c1', 'c1c-c2cc3cnc4ccc5ccccc5c4c3cc2-nc1', 'c1cnc2cc3c(cnc4ccc5ccccc5c43)cc2c1']
values = [29.863410723178852, 31.711544415807257, 31.716638633698157, 31.711544415807257, 31.711544415807257]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### REINVENT

# %% [markdown]
# #### Function 1

# %%
smiles = ['c1ccc(-c2sc(-c3ccc(-c4nccc5nsnc45)[se]3)c3nccnc23)cc1', 'c1cncc(-c2cnc(-c3cnc(-c4cccc5cscc45)c4nsnc34)s2)c1', 'c1ccc(-c2cnc(-c3ccc(-c4scc5nccnc45)cn3)c3nsnc23)nc1', 'c1ccc(-c2ccc(-c3cnc(-c4nccs4)c4nsnc34)nc2)cc1', 'c1ccc(-c2cnc(-c3sc(-c4cccnc4)c4nccnc34)s2)cc1']
values = [7.3710911994656065, 7.43265123021753, 7.566773508759241, 7.393748619452403, 7.63047601101457]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function 2

# %%
smiles = ['c1ccc2c(c1)ccc1ncc3c4oc(-c5cccc6cocc56)cc4c4cocc4c3c12', 'C1=c2cccc(-c3ccc4c(ccc5c6occc6c6ccccc6c45)c3)c2=C[SiH2]1', 'c1ccc(-c2ccc(-c3cnc(-c4cccc5c[nH]cc45)s3)[nH]2)nc1', 'c1cc(-c2cc3ncc4c(ncc5cc[nH]c54)c3c3cocc23)c2cocc2c1', 'c1ccc2c(c1)ccc1ccc3c([nH]c4cc(-c5scc6ccsc56)sc43)c12']
values = [30.61787734144375, 30.206089879645397, 31.13633007992535, 30.0031755949596, 30.400350076533922]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### VAE-SMILES

# %% [markdown]
# #### Function 1

# %%
smiles = ['c1ccc(cn1)-c1sc(-c2ncc(s2)-c2cccc3nsnc23)c2nccnc12', 'c1ccc(cn1)-c1sc(-c2ncc(s2)-c2cccc3nsnc23)c2nccnc12', 'c1ccc(cn1)-c1sc(-c2ncc(s2)-c2cccc3nsnc23)c2nccnc12', 'c1ccc(cn1)-c1sc(-c2ncc(s2)-c2cccc3nsnc23)c2nccnc12', 'c1ccc(cn1)-c1sc(-c2Cc(cc2)-c2cccc3ncncc23)c2nccnc12']
values = [7.577355332181861, 7.59234692751969, 7.592516217678796, 7.572015441486025, 6.877241071393954]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function 2

# %%
smiles = ['c1sc(-c2cc3cc4cc5ccc6c[cH]cc6c5cc4c3c3cscc23)c2nccnc12', 'c1sc(-c2ccc3c4cc5ccccccccc6cnncccc6cc5c4c3c2)c2ncccc12', 'c1sc(-c2cc3cc4c(cnc5ccc6c[nH]cc6c45)c3c3nCCc23)c2nccnc12', 'c1sc(-c2cc3cc4cc5ccc6c[cH]cc6c5cc4c3c3cscc23)c2nccnc12', 'c1sc(-c2cc3ccc4c(ccc5ccc6csnc6c45)c3c3cscc23)c2occc12']
values = [18.241606104567474, -3.186769454208494, 21.372564352995457, 18.239746555133692, -3.497737223165168]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### VAE-SELFIES

# %% [markdown]
# #### Function 1

# %%
smiles = ['C1=CC=C(C=N1)C=5SC(C2=NC=C(S2)C3=CC=CC4=NSN=C34)=C6N=CC=NC=56', 'C1=CC=C(C=C1)C=5SC(C=3SC(C2=CC=NC=N2)=C4N=CC=NC=34)=C6C=CSC=56', 'C1=CC=C(C=N1)C=5SC(C2=CC=C(C2)C3=CC=CC4=NSN=C34)=C6N=CC=NC=56', 'C1=CC=C(C=N1)C=5SC(C2=NC=C(S2)C3=CC=CC4=NSN=C34)=C6N=CC=NC=56', 'C1=CC=C(S1)C=5SC(C2=NC(=CS2)C3=CC=CC4=NSN=C34)=C6N=CC=NC=56']
values = [7.590900978001798, 7.527945025521813, 5.969844205551706, 7.593447563520394, 6.582915660545063]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function 2

# %%
smiles = ['C=7SC(C5=CC4=CC=C2C([Se]C=3C=CC1=CCC=C1C2=3)=C4C6=CSC=C56)=C8[NH]CCC=78', 'C=4SC1(C=C2C3OC=C(CC=CC=CC=C1C=C2C=C=CCC35))(N=CC=NC=45)', 'C=4SC(C=CCOC2=C(C=CC3C=CC1=CCC=C1C23)C=NC)=C5C=CCC=45', 'C=5SC(C2=CC3=CC=CC(C1=CCC=C1C#C)=NC24C=CSC=C34)=C6[NH]C=CC=56', 'C=5SC(C=CC=2OC3=C(CC)CCC=CC=C1C=C1C=2C4=CC=CC=C34)=C6C=C=CC=56']
values = [30.078515202929772, 29.926185948462482, 29.012332868375193, 28.471629496171165, 28.719538968807736]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img
