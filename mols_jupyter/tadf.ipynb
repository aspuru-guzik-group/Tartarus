# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
# ### Best of Dataset

# %%
smiles = ['NC1=C2SC3=C(N2C=N1)C(=O)C=N3',
          'C=CC=CC=C1C=CC(=C)C=C1', 
          'NC1=C(N)C(OC2=NSC=C2)=CN1']

values = [0.002494315632930233, 2.973710069218942, -0.03515370375207447]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=3,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# ### JANUS

# %% [markdown]
# #### Singlet_triplet

# %%
smiles = ['C=CNC=C(N)C(=O)N=C=CC1C=CCC(N)=C(OC=O)C(NC=C(C=O)SC=NC(N)=C(N)OO)=CN1', 'NC1=NOC1CCCC=CC1=CN=NC1=CC(=S)c1c(N)c(=O)c(=O)c1=O', 'C=C[SH]=CC(=CN)NC(=O)OOC(N)N(COC=CC)C(=O)NC=CC1c2ncnnc2-n2cccc21', 'C=NC(=O)C=NNC=NCNC=CC(N)=CN=NC=CCc1occ2c1S1(OC(=O)NC=C1C=O)C(=O)N2C=O', 'C=CC=CC(CNC)NC(=N)CNC(O)=CC=NC=C(C)NNC1C=CC=C(OCC=C(N)C2=C(N)OC2=O)N1']
values = [0.0005557497818291512, 0.00038516946735239754, 1.4530563726466994e-05, 0.0006106357096412607, 0.00037007641637720745]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Oscillator Strength

# %%
smiles = ['C=CC=CC=C1C=CC(=C)C=C1', 'C=CC=CC=C1C=CC(=C)C=C1', 'C=CC=CC=C1C=CC(=C)C=C1', 'C=c1ccc(=CC=CC=CBr)cc1', 'C=CC=CC=C1C=CC(=C)C=C1']
values = [2.705650769541478, 2.9737331969452274, 1.7527841731807403, 3.352042757935889, 2.9737313155796508]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function

# %%
smiles = ['NC=C(N)C=CC=CNC=NNN=NC=C(N)C=CO', 'NC1=C(N)C(OC2=NSC=C2)=CN1', 'NC1=C(N)C(OC2=NSC=C2)=CN1', 'Nc1[nH]cc(Oc2ccsn2)c1N', 'NC1=CC2=C(NC(O)=C2OC=O)S1']
values = [0.4395641621177222, -0.03515590982993625, -0.050839734553352736, -0.04882174503156157, -0.2223095532814812]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### GB-GA

# %% [markdown]
# #### Singlet Triplet

# %%
smiles = ['Nc1c2c(c3occ(NOC4=c5ccoc5=[SH]CO4)n13)C(N)CC1C=[SH]C=C21', 'NC(=O)NC(=O)C(=O)C=COOc1nc(C2=[SH]C3=c4c(coc4=[SH]C=C3)N2)c[nH]1', 'O=COc1cc2c(C3=NC=[SH]C=C3Oc3cc4c(C5=NC=[SH]C=C5O)[nH]oc-4n3)[nH]oc-2n1', 'C=C1SN=[SH]C(=O)C1c1n[nH]n2c(C(=O)C=O)c3c(c2c1=O)C1OC=[SH]CC1O3', 'O=c1ncc2c(CNOC3=NCl=C4C=NC=C34)nccc2s1']
values = [0.0003630772502165591, 0.0053451832470488014, 0.00033125780450982134, 0.0014602873678356554, 0.0008940398931192028]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img
# Out:
# [14:29:28] Explicit valence for atom # 11 Cl, 3, is greater than permitted

# %% [markdown]
# #### Oscillator Strength

# %%
smiles = ['C=Cc1ncc(C=CC=CC=CC=CC=Cc2coc3c[nH]nc23)[nH]1', 'C=COC=CC=CC=CC=COC=C', 'C(=CC=Cc1cn[nH]c1)C=Cc1cn[nH]c1', 'Nc1oc(C=Cc2ncc(C3=NC=CC3)o2)nc1O', 'C=c1ccc(=CC=Cc2cn3c(n2)oc2cncn23)cc1']
values = [4.273899135659052, 3.316761790801399, 2.529777053183235, 2.555273655243506, 2.975545872177513]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function

# %%
smiles = ['c1scc2c1ncn1c(-c3ncc4c5cscc5ncn34)ncc21', 'Nc1cc2n(n1)C=NC(Oc1coc(N)c1)O2', 'O=Cc1cnc(-c2ncc(-c3cnc(-c4ncc(C=O)o4)s3)s2)o1', 'C=Cc1nnc(-c2cnc(-c3cccs3)s2)s1', 'NC1C=C(C(=O)O)Oc2nc(=O)ccn21']
values = [0.038008169607719466, -0.09894985875757843, 0.6286619960799715, -0.01908569604299415, -0.20659142431033004]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### VAE-SELFIES

# %% [markdown]
# #### Singlet Triplet

# %%
smiles = ['NC=CNCOCC(CCCCCCC=O)', 'NC=COC(CC=CC=CC=CCC=S)', 'NC=COCOCC=C1OC=CC1C=CC=O', 'NC=NC(O)=CC=CS1C=CCCC=C1', 'NC=CN(C=C)C=C(C)OCCC=O']
values = [1.027916189100253e-05, 0.00045956899469201673, 0.0001897610042194131, 0.0034254516800305, 0.00012114958522646546]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Oscillator Strength

# %%
smiles = ['C=CC=CC=NC=CN=CC=CC=NO', 'C=CC=CC=CC=CC=CC1=CC1', 'C=CC=CC=CC=CC=CC=CC=C', 'C=CC=CC=CC=CC=CC=CC=C', 'C=CC=NC=CC=CC=CC=CC#N']
values = [4.397106227051529, 3.2929748148195923, 4.311506608673119, 4.308420430687011, 3.9622091969479496]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function

# %%
smiles = ['NC=COC=NC=CC=CC=C=C=CN', 'NC=CC(OC=C)=CC=CC=C=C=CS', 'NC=C(NC=C(OC))CC=CC=C', 'N1C=C(NC2=CN1C(=C(C))O2)OC', 'NC=C(O)C=C(C=CC=CC1=CC=CN1)']
values = [1.4107356783538578, 0.579723440571676, -0.04197229631679379, 0.3583572746345871, 0.6961591230515971]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### VAE-SMILES

# %% [markdown]
# #### Singlet Triplet

# %%
smiles = ['O=C1SS=SOOS1', 'C=CNCCCN=CCC', 'C=CN1CCN=CCCNCC1', 'C=CNC1=C=CCC1', 'NC=CCCCC=CC=C']
values = [0.04016784675896545, 0.0634878456231065, 0.08274646306839939, 0.10894150153432913, -1.0]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Oscillator Strength

# %%
smiles = ['C=CC1=CNNC=CCCCCCCCCC=C1', 'C=C1C=CC2=CCCC=CCC=CCC1CO2', 'C=CC1=CC2=CCCCCC=CCC2CO1', 'N1C=NC2=CC=CCCCCC=CCC=C12', 'C=CC1=C2C=CC=CCC=CC2C=N1']
values = [0.2852807532951764, 0.4175882115965768, 0.941837197035404, 0.4095203946586179, 0.4020030564997499]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function

# %%
smiles = ['O=C1C=CC2C=CCCCC=CCC=C12', 'C=CC1=CNCC=CCCCC=CCCC=N1', 'C=C1NC=CNN=CCCCC=CCCC=C1', 'C=C1C=CC2NC=CCCCCCC=CCC=C12', 'O=CN1C2=NNC=CC=CCCC=C12']
values = [-0.5977999768364721, -0.48785481589795565, -0.3192082618983108, -1.1635795533043383, -0.275442849019145]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### REINVENT

# %% [markdown]
# #### Singlet Triplet

# %%
smiles = ['NC(=S)n1c(=O)ncc2cocc21', 'C=C(C=O)Oc1cnncc1O', 'Nc1cc(=O)ccc2oc(=O)sc12', 'Nc1ccc2n1sc1noc(O)c12', 'Nc1cncn1-c1csc(C=O)c1']
values = [0.06007769583627098, 0.02966521313202941, 0.02587263308665766, 0.06456230900082494, 0.015546509169213518]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Oscillator Strength

# %%
smiles = ['c1cc2[nH]c(-c3cn[nH]c3)nc2o1', 'C=Cc1nc2[nH]c(C=C)nc2o1', 'C=Cc1ncc(-c2oncc2O)[nH]1', 'C=c1ccc(=COC=O)cc1', 'C(=Cc1ccc[nH]1)c1ccncc1']
values = [0.89503181166943, 1.362259070348414, 1.036059900097769, 1.253896527985133, 1.250499847764782]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function

# %%
smiles = ['NC(=S)N1C=Cc2ccnnc21', 'NC(=S)Nc1nncc2ccoc12', 'C=Cc1csc2c1ncn2C(C=O)O', 'Nc1c(Oc2cscn2)csc1O', 'O=CN(C=O)c1cc2[nH]c(O)cn2c1']
values = [-0.19450622350859814, -0.21243773464681898, -0.11355216467221128, -0.17326732886712842, -0.12439302844151408]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### HillClimbing SELFIES

# %% [markdown]
# #### Singlet Triplet

# %%
smiles = ['Nc1ccc2[nH]c(O)cn12', 'Nc1ccc2[nH]c(O)cn12', 'Nc1ccc2[nH]c(O)cn12', 'Nc1ccc2[nH]c(O)cn12', 'Nc1ccc2[nH]c(O)cn12']
values = [0.05826905574976493, 0.05826907651384339, 0.05826909270922975, 0.058269153515129624, 0.05826911949728286]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Oscillator Strength

# %%
smiles = ['C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1']
values = [0.9952503392907166, 0.9952503392907609, 0.9952503392907399, 0.995250339290751, 0.9952503392907369]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function

# %%
smiles = ['C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1']
values = [-0.24548407974170153, -0.2446537685125528, -0.24636550233400628, -0.25052757126834047, -0.2499120298114154]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# ### HillClimbing SMILES

# %% [markdown]
# #### Singlet Triplet

# %%
smiles = ['Nc1ccc2[nH]c(O)cn12', 'Nc1ccc2[nH]c(O)cn12', 'Nc1ccc2[nH]c(O)cn12', 'c1cc2cnnc-2ccn1', 'Nc1ccc2[nH]c(O)cn12']
values = [0.058269131933288865, 0.05826910192501167, 0.058269130158468574, 0.011521336843280106, 0.05826911696603476]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Oscillator Strength

# %%
smiles = ['C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1', 'C=Cc1ccc(C=C)[nH]1']
values = [0.9952503392907103, 0.9952503392907192, 0.9952503392907257, 0.9952503392907488, 0.9952503392907578]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img

# %% [markdown]
# #### Function

# %%
smiles = ['C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1', 'C=Cc1nc(=O)cc(N)o1']
values = [-0.24835253498868232, -0.24464421419290228, -0.24627889132018835, -0.24570917739285522, -0.24664315297703454]
mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(250,250),legends=[str(x) for x in values])
img
