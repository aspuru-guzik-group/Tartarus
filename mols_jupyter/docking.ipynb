# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
# ### Best of Dataset

# %%
smiles = ['O=C1c2c(C(=CC1=O)Nc1[nH]ncn1)cccc2',
          'Clc1ccc(C(=O)NNC(=O)C2CCN(S(=O)(=O)c3ccc(cc3)c3ccccc3)CC2)cc1', 
          'O=C1NC2N(NC31c1c(-c4c3cccc4)cccc1)C(=O)C(=O)NN2']

# Order: 1syh, 4lde, 6y2f
values = [-10.1, -13.0, -8.2]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=3,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# ## Native Docking

# %%
smiles = ['N[C@@H](CN1C(=O)NC(=O)C2=C1CCC2)C(O)=O',
          'Cc1ccccc1CC(C)(C)NC[C@H](O)c2ccc(O)c3NC(=O)COc23',
          'CC(C)(C)OC(=O)NC1=CC=CN([C@@H](CC2CC2)C(=O)N[C@@H](C[C@@H]3CCNC3=O)[C@@H](O)C(=O)NCc4ccccc4)C1=O']

# Order: 1syh, 4lde, 6y2f
values = [-10.2, -11.6, -4.9]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=3,subImgSize=(200,200),legends=[str(x) for x in values])    
img

# %% [markdown]
# ## VAE SMILES

# %% [markdown]
# #### 1SYH

# %%
smiles = ['SCC1(Ncccccc1)C(O)N1NC(O)OC1',
         'Clc1cc(ccccc1)C(=O)N(NO)O',
         'S1c(Cc2ccc(c(N)c2NN)C(O)N)CC1',
         'N(CC(c1ccccc1))C(N)NC(=O)OCN',
         'Clc1cc2c(cc2)c(c(=O)c1NNN)/N=N/NC']

values = [-6.7, -9.6, -8.3, -8.0, -8.7]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0E1C3D0>

# %% [markdown]
# #### 4LDE

# %%
smiles = ['O(c1c([N+](=O)[O-])cc([N+](=O)[O-])cc1)c1ccc(O)c(OC)c1',
         'O(c1c([N+](=O)[O-])cc([N+](=O)[O-])cc1)c1ccc(CC(=O)C)cc1',
         'O(c1c([N+](=O)[O-])ccc([N+](=O)[O-])c1)c1ccc(C)c(O)c1',
         'O(c1c([N+](=O)[O-])c(c([N+](=O)[O-])cc1)c1ccccc1)C(=O)OO',
         'O(c1c([N+](=O)[O-])cc([N+](=O)[O-])cc1)C(=O)c1ccccc1CCCOO']

values = [-6.6, -6.1, -6.2, -6.0, -6.5]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DAD850>

# %% [markdown]
# ## VAE SELFIES

# %% [markdown]
# #### 1SYH

# %%
smiles = ['O(N2[NH][NH][NH]1)[NH]C1=N[NH]C=C2C=CC=O',
         'O=C1CC1CCCC2NN=NN=C2N=NN=NN=NN',
         'OC=C1CNC(CC=NC[NH]C=O)=CC=C1',
         'O(N=C1(C(=O)[NH]C=C))C=CC=C2C=CC=C12',
         'O1N=NNN=C1C(=O)C(=O)CC2CC2=NN=NOC']

values = [-9.3, -9.4, -8.6, -9.6, -9.5]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD3210E5390>

# %% [markdown]
# #### 6Y2F

# %%
smiles = ['O1NNN=C1(NC=NC=CC=O)',
         'O1NNN=C1(NC=NC=CC=O)',
         'O1NNN=C1(NC=NC=CC=O)',
         'O1NNN=C1(NC=NC=CC=O)',
         'O1NNN=C1(NC=NC=CC=O)']

values = [-7.7, -7.7, -7.7, -7.7, -7.7]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DADF10>

# %% [markdown]
# #### 4LDE

# %%
smiles = ['O=CNC=1C(CCCC=1C=O)=CC=CC=CC2=CC=CC=C2O',
         'O(CCNNNNC=CC=CC=C(C=CC)C)C1=CC=CC(=C)C=C2C1(C2)',
         'O(CC(NNC(=O)CC=CC=C)C=O)C(=O)CC=CC=CC1=CCCC=C1C(O)OO',
         'OCC(C)CCC(C=CC(C(C13)C12))C2=CC=CC=C3C(C)=O',
         'OC=C(NON=CN)CC=CC=CC(C1)CCC1(C2(O3)C)C23N']

values = [-11.0, -10.7, -10.0, -9.6, -9.9]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DD1610>

# %% [markdown]
# ## GB-GA

# %% [markdown]
# #### 1SYH

# %%
smiles = ['Cc1cc(CO)c(O)c2ncccc12',
         'O=C(O)c1[nH]c(=O)c2ccccc2c1NO',
         'NC(Cc1c(O)[nH]c2ccccc12)C(=O)O',
         '[N-]=[N+]=NS(=O)(=O)c1cccc2c1NCN2',
         'O=C(O)CC1=CC(=O)c2ccccc2C1=O']

values = [-9.7, -10.8, -10.4, -9.9, -10.5]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD323955F90>

# %% [markdown]
# #### 4LDE

# %%
smiles = ['CC1C=CC(C(=O)/C=C/c2ccccc2O)=C1C(C(N)=O)c1c(Cl)n(C)c2ccccc12',
         'Cc1ccc(OON2C(=O)c3cccc4cc5c(c(c34)C2=O)CCCC5)cc1C',
         'C[C@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)[C@H](C)C[C@]4(C)[C@@]3(F)C(=O)C[C@]12C',
         'CNC(=O)c1nn(-c2cccc(/C=C\\c3ccc(O)cc3)c2)c2oc(=O)cc(C)c12',
         'C[C@H]1CC2C3CC[C@H](N)[C@@]3(C)CC(O)C2[C@@]2(C)CCC(=O)C=C12']

values = [-12.4, -12.4, -16.8, -13.1, -16.0]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD3210E5490>

# %% [markdown]
# #### 6Y2F

# %%
smiles = ['O=C1C=C2C=C[C@@H]3C[C@@]2(O1)[C@H]1CCCCN31',
         'CC1CCc2ccc(/C(CC3(O)C(=O)Nc4ccccc43)=N\\NC(=O)C(=O)NN)cc2C1',
         'CC1C2C(CC3C4C(O)CC5CC(O)CCC5(C)C4C(O)CC32C)OC12CCC(O)CN2',
         'O=C1C=C2C=C[C@@H]3C[C@@]2(O1)[C@H]1CCCCN31',
         'Cc1cnc(-n2c(C)nc3c(c2=O)=C(Cl)CC=3C2(C)N=C(N)Nc3nc4ccccc4n32)s1']

values = [-10.6, -8.9, -8.9, -10.6, -9.1]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DADC90>

# %% [markdown]
# ## Reinvent

# %% [markdown]
# #### 1SYH

# %%
smiles = ['C[C@]12CC[C@H]3[C@@H](CC[C@H]4CC(=O)NCC43C)[C@@H]1CCC2=O',
         'C[C@]12CCCC3[C@@H](CCC4=CC(=O)CCC43C)C1CCC2=O',
         'O=C(NCCN1CCOCC1)NC1OCC(O)C(O)C1O',
         'C[C@]12CC[C@H]3[C@@H](CCC4=CC(=O)OCC[C@H]43)C1CCC2=O',
         'N#CCCCC(=O)Nc1nnc(C2OCC(O)C(O)C2O)s1']

values = [-15.9, -17.4, -11.0, -15.8, -10.6]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DD1150>

# %% [markdown]
# #### 4LDE

# %%
smiles = ['COC(=O)Nc1cccc(NC(=O)n2nc(N)c3ccccc3c2=O)c1',
         'O=C(Nc1cccc2ccccc12)N1OCC[C@H]1c1ccccc1',
         'COC(=O)[C@@H]1CC[C@H]2[C@@H]3CCC4=CC(=O)C[C@]4(C)C[C@H]3CC[C@]12C',
         'O=C1C=C([C@H]2CC(O)C(CO)CC2)CC=C1c1cccc2ccccc12',
         'O=C(Nc1ccc(C(F)(F)F)cc1)C(=O)CC1(O)C(=O)Nc2ccc3ccccc3c21']

values = [-12.0, -12.1, -16.4, -11.8, -11.9]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DD1510>

# %% [markdown]
# #### 6Y2F

# %%
smiles = ['C[C@]12CCC(=O)C[C@H]1CC[C@@H]1C2CCC2(C)C(=O)CC[C@]12C',
         'O=C1c2cccnc2[C@]12C=CC1=CC(=O)CC[C@@H]12',
         'CC1=C2[C@H](OC3=C2C(=O)c2c(O)ccc(O)c3CC2C)NC(=S)N1C1CCCCO1',
         'COC(=O)c1cc2c(c(C(N)=O)n1)NC(=O)CN(/C=C/C(=O)c1ccccc1)O2',
         'O=C(COc1ccc(C(=O)NO)cc1)NN=C(c1ccc(O)cn1)c1ccc(C(=O)O)cc1']

values = [-14.6, -11.9, -8.1, -8.1, -8.1]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DD1790>

# %% [markdown]
# ## Hill Climbing (SMILES)

# %% [markdown]
# #### 1SYH

# %%
smiles = ['CC(C1CCCC(=NNC(N)=O)C1)[N+](=O)[O-]',
         'COC(=O)C=C1Nc2c(N)nc(N)nc2NC1=O',
         'O=C(O)c1cc(=O)oc2cc(O)c(O)cc12',
         'CC(C1CCCC(=NNC(N)=O)C1)[N+](=O)[O-]',
         'CC(C1CCCC(=NNC(N)=O)C1)[N+](=O)[O-]']

values = [-10.0, -10.1, -10.1, -10.0, -10.0]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DCA750>

# %% [markdown]
# #### 4LDE

# %%
smiles = ['C[C@]12CCC(=O)C[C@H]1CC[C@@H]1C2CCC2(C)C(=O)CC[C@]12C',
         'O=C1c2cccnc2[C@]12C=CC1=CC(=O)CC[C@@H]12',
         'CC1=C2[C@H](OC3=C2C(=O)c2c(O)ccc(O)c3CC2C)NC(=S)N1C1CCCCO1',
         'COC(=O)c1cc2c(c(C(N)=O)n1)NC(=O)CN(/C=C/C(=O)c1ccccc1)O2',
         'O=C(COc1ccc(C(=O)NO)cc1)NN=C(c1ccc(O)cn1)c1ccc(C(=O)O)cc1']

values = [-14.6, -11.9, -8.1, -8.1, -8.1]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DD1910>

# %% [markdown]
# #### 6Y2F

# %%
smiles = ['O=[N+]([O-])c1ccc(NN=C(c2ccccc2)C2OCCC2c2ccccc2)c([N+](=O)[O-])c1',
         'CC=C(C)C(=O)OC1C2C(C)=CC(O)C(O)C2(C)C2C3(O)OCC24C(CC(=O)OC14)C(C)C3O',
         'O=c1[nH]c(=O)c2nc3c([N+](=O)[O-])ccc(-c4cccc5ccccc45)c3nc2[nH]1',
         'O=[N+]([O-])c1ccc(NN=C(c2ccccc2)C2OCCC2c2ccccc2)c([N+](=O)[O-])c1',
         'O=c1[nH]c(=O)c2nc3c([N+](=O)[O-])ccc(-c4cccc5ccccc45)c3nc2[nH]1']

values = [-8.7, -8.6, -8.6, -8.6, -8.6]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD32A4F7B50>

# %% [markdown]
# ## Hill Climbing (SELFIES)

# %% [markdown]
# #### 1SYH

# %%
smiles = ['O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12',
         'O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12',
         'Cc1cccc2c1CC(=Cc1cccc(C)c1C(=O)O)C2=O',
         'O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12',
         'O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12']

values = [-11.8, -11.8, -11.8, -11.8, -11.8]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DDDD10>

# %% [markdown]
# #### 4LDE

# %%
smiles = ['O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12',
             'O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12',
             'Cc1cccc2c1CC(=Cc1cccc(C)c1C(=O)O)C2=O',
             'O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12',
             'O=C(NN=Cc1ccc2c(c1)CCC2)c1cccc2ccccc12']

values = [-11.8, -11.8, -11.8, -11.8, -11.8]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DE1150>

# %% [markdown]
# #### 6Y2F

# %%
smiles = ['O=[N+]([O-])c1ccc(NN=C(c2ccccc2)C2OCCC2c2ccccc2)c([N+](=O)[O-])c1',
         'O=[N+]([O-])c1ccc(NN=C(c2ccccc2)C2OCCC2c2ccccc2)c([N+](=O)[O-])c1',
         'CN(NC(=O)C(=Cc1ccc(O)cc1)NC(=O)c1ccccc1)c1ccnc2cc(Cl)ccc12',
         'O=c1[nH]c(=O)c2nc3c([N+](=O)[O-])ccc(-c4cccc5ccccc45)c3nc2[nH]1',
         'O=[N+]([O-])c1ccc(NN=C(c2ccccc2)C2OCCC2c2ccccc2)c([N+](=O)[O-])c1']

values = [-8.7, -8.6, -8.7, -8.6, -8.6]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DE16D0>

# %% [markdown]
# ## JANUS

# %% [markdown]
# #### 1SYH

# %%
smiles = ['OOOCC1=C(O)C2=NC=CCC2C(O)=C1',
         'O=C=C(Cc1ccccc1Cl)C(O)C(=O)O',
         'O=c1[nH]c2ccccc2n(O)c1=NNNO',
         'O=NC1=CC(=C(O)O[N+](=O)[O-])C=C1C(=O)O',
         'NC=C1N=C(NC(=O)O)C(=O)c2ccccc21']

values = [-11.1, -10.2, -10.8, -10.2, -11.3]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0DE1610>

# %% [markdown]
# #### 4LDE

# %%
smiles = ['CC(CC1=CC=CC=C(C(=O)O)C1)=NNN(N)O',
         'ON=C(O)c1ccc(C2NONO2)c(O)c1',
         'NNOOc1cc2cc(n1)C(COOO)OC=C2',
         'NC(=O)c1cc(CCOO)c(N)cc1C(=O)OO',
         'O=C(O)CC1CCc2c(O)cccc2C1=O']

values = [-11.2, -12.2, -12.1, -10.5, -10.9]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A241C2D0>

# %% [markdown]
# #### 6Y2F

# %%
smiles = ['O=C(O)c1cc(O)c(CCOO)cc1O',
         'NC(C(=O)OC(=O)O)c1cc(OO)c(O)cc1O',
         'CC(O)C1(O)CC(C2OOOO2)=C(O)CO1',
         'CNC(=O)C(=O)c1cc(N)c(C(=O)O)cc1[N+](=O)[O-]',
         'CC1=C(C=CO)C=C(O)OC(C(=O)O)=C1']

values = [-10.0, -10.6, -11.7, -10.0, -10.4]

mols_ls = [Chem.MolFromSmiles(x) for x in smiles]
img = Draw.MolsToGridImage(mols_ls,molsPerRow=5,subImgSize=(200,200),legends=[str(x) for x in values])    
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x200 at 0x7FD2A0E26310>
